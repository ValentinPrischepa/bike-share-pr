# %%
import os
import glob
import pandas as pd
from datetime import datetime
import zipfile

# It's a good practice to set up your directory paths at the beginning.
# Replace these with the actual paths on your system.
RAW_DATA_DIR = '/Users/vpry/Downloads/bike_sharing_dataset'
PROCESSED_DATA_DIR = '/Users/vpry/Downloads/processed_data/'

# Create the processed data directory if it doesn't exist
os.makedirs(PROCESSED_DATA_DIR, exist_ok=True)

def process_and_save_data(file_path):
    """
    Reads a single zip file, selects 'start_at' and 'end_at' columns,
    and saves a new compressed CSV file. This version correctly handles
    multiple files inside the zip archive and renames columns.

    Args:
        file_path (str): The full path to the input .zip file.
    """
    try:
        # Step 2a: Read the compressed CSV file directly into a pandas DataFrame.
        # pandas can handle reading compressed files automatically.
        print(f"Processing file: {os.path.basename(file_path)}...")

        # Use the zipfile library to open the archive and find the specific CSV file.
        # This handles cases where extra files like __MACOSX are present.
        with zipfile.ZipFile(file_path, 'r') as zf:
            csv_file_in_zip = None
            for name in zf.namelist():
                if name.endswith('.csv') and not name.startswith('__MACOSX'):
                    csv_file_in_zip = name
                    break
            
            if csv_file_in_zip:
                # Step 2b: Read the actual CSV data from the file inside the zip.
                # The nrows=0 has been removed to read all data.
                df = pd.read_csv(zf.open(csv_file_in_zip))

                # Step 2c: Rename columns for standardization. This is a great practice!
                df = df.rename(columns={'Start date': 'start_at', 'End date': 'end_at', 'started_at':'start_at', 'ended_at':'end_at'})

                # Step 2d: Ensure the standardized columns are present.
                required_columns = ['start_at', 'end_at']
                if not all(col in df.columns for col in required_columns):
                    print(f"Skipping {os.path.basename(file_path)}: Missing required columns after renaming.")
                    return

                # Per user request, the duration calculation has been removed from this step.
                # We will keep the 'start_at' and 'end_at' columns as strings for later processing.

                # Step 2e: Select the final columns to be saved.
                final_df = df[['start_at', 'end_at']].copy()

                # Step 2f: Construct the output file path.
                # We'll use the same base name but change the extension to .csv.gz
                file_name = os.path.basename(file_path).replace('.zip', '.csv.gz')
                output_file_path = os.path.join(PROCESSED_DATA_DIR, file_name)

                # Step 2g: Save the new DataFrame to a compressed CSV file.
                # compression='gzip' handles the compression automatically.
                final_df.to_csv(output_file_path, index=False, compression='gzip')
                print(f"Successfully saved cleaned data to: {output_file_path}")
            else:
                print(f"An error occurred while processing {file_name}: No CSV file found in the archive.")

    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

# 3. Main Script Execution
# ==============================================================================
if __name__ == '__main__':
    # Step 3a: Use glob to find all .zip files in the raw data directory.
    zip_files = glob.glob(os.path.join(RAW_DATA_DIR, '*.zip'))

    if not zip_files:
        print(f"No .zip files found in the directory: {RAW_DATA_DIR}. "
              "Please make sure your raw data files are there.")
    else:
        print(f"Found {len(zip_files)} files to process.")
        # Step 3b: Loop through each file and call the processing function.
        for file in zip_files:
            process_and_save_data(file)

        print("\nAll files have been processed.")
# Out:
# Found 97 files to process.
# Processing file: 202210-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202210-capitalbikeshare-tripdata.csv.gz
# Processing file: 202503-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202503-capitalbikeshare-tripdata.csv.gz
# Processing file: 202012-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202012-capitalbikeshare-tripdata.csv.gz
# Processing file: 201909-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201909-capitalbikeshare-tripdata.csv.gz
# Processing file: 202305-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202305-capitalbikeshare-tripdata.csv.gz
# Processing file: 201802-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201802-capitalbikeshare-tripdata.csv.gz
# Processing file: 202408-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202408-capitalbikeshare-tripdata.csv.gz
# Processing file: 202107-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202107-capitalbikeshare-tripdata.csv.gz
# Processing file: 202003-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202003-capitalbikeshare-tripdata.csv.gz
# Processing file: 201906-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201906-capitalbikeshare-tripdata.csv.gz
# Processing file: 202201-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202201-capitalbikeshare-tripdata.csv.gz
# Processing file: 202108-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202108-capitalbikeshare-tripdata.csv.gz
# Processing file: 202407-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202407-capitalbikeshare-tripdata.csv.gz
# Processing file: 2012-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2012-capitalbikeshare-tripdata.csv.gz
# Processing file: 201910-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201910-capitalbikeshare-tripdata.csv.gz
# Processing file: 202504-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202504-capitalbikeshare-tripdata.csv.gz
# Processing file: 202209-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202209-capitalbikeshare-tripdata.csv.gz
# Processing file: 201805-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201805-capitalbikeshare-tripdata.csv.gz
# Processing file: 202411-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202411-capitalbikeshare-tripdata.csv.gz
# Processing file: 202302-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202302-capitalbikeshare-tripdata.csv.gz
# Processing file: 202206-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202206-capitalbikeshare-tripdata.csv.gz
# Processing file: 201901-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201901-capitalbikeshare-tripdata.csv.gz
# Processing file: 2015-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2015-capitalbikeshare-tripdata.csv.gz
# Processing file: 202111-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202111-capitalbikeshare-tripdata.csv.gz
# Processing file: 2013-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2013-capitalbikeshare-tripdata.csv.gz
# Processing file: 202109-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202109-capitalbikeshare-tripdata.csv.gz
# Processing file: 201812-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201812-capitalbikeshare-tripdata.csv.gz
# Processing file: 202406-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202406-capitalbikeshare-tripdata.csv.gz
# Processing file: 202002-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202002-capitalbikeshare-tripdata.csv.gz
# Processing file: 201907-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201907-capitalbikeshare-tripdata.csv.gz
# Processing file: 201803-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201803-capitalbikeshare-tripdata.csv.gz
# Processing file: 202409-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202409-capitalbikeshare-tripdata.csv.gz
# Processing file: 202106-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202106-capitalbikeshare-tripdata.csv.gz
# Processing file: 202304-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202304-capitalbikeshare-tripdata.csv.gz
# Processing file: 202502-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202502-capitalbikeshare-tripdata.csv.gz
# Processing file: 201908-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201908-capitalbikeshare-tripdata.csv.gz
# Processing file: 202211-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202211-capitalbikeshare-tripdata.csv.gz
# Processing file: 202110-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202110-capitalbikeshare-tripdata.csv.gz
# Processing file: 202401-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202401-capitalbikeshare-tripdata.csv.gz
# Processing file: 202312-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202312-capitalbikeshare-tripdata.csv.gz
# Processing file: 2014-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2014-capitalbikeshare-tripdata.csv.gz
# Processing file: 202005-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202005-capitalbikeshare-tripdata.csv.gz
# Processing file: 202207-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202207-capitalbikeshare-tripdata.csv.gz
# Processing file: 202303-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202303-capitalbikeshare-tripdata.csv.gz
# Processing file: 201804-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201804-capitalbikeshare-tripdata.csv.gz
# Processing file: 202410-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202410-capitalbikeshare-tripdata.csv.gz
# Processing file: 202101-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202101-capitalbikeshare-tripdata.csv.gz
# Processing file: 202208-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202208-capitalbikeshare-tripdata.csv.gz
# Processing file: 201911-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201911-capitalbikeshare-tripdata.csv.gz
# Processing file: 202505-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202505-capitalbikeshare-tripdata.csv.gz
# Processing file: 202311-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202311-capitalbikeshare-tripdata.csv.gz
# Processing file: 2017-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2017-capitalbikeshare-tripdata.csv.gz
# Processing file: 201808-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201808-capitalbikeshare-tripdata.csv.gz
# Processing file: 202402-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202402-capitalbikeshare-tripdata.csv.gz
# Processing file: 202204-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202204-capitalbikeshare-tripdata.csv.gz
# Processing file: 202006-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202006-capitalbikeshare-tripdata.csv.gz
# Processing file: 201903-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201903-capitalbikeshare-tripdata.csv.gz
# Processing file: 201807-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201807-capitalbikeshare-tripdata.csv.gz
# Processing file: 202102-capitalbikeshare-tripdata.zip...
# /var/folders/1l/10knfvms6fl6hf1wl_blq_sm0000gn/T/ipykernel_19452/3361591023.py:41: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(zf.open(csv_file_in_zip))
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202102-capitalbikeshare-tripdata.csv.gz
# Processing file: 202506-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202506-capitalbikeshare-tripdata.csv.gz
# Processing file: 202009-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202009-capitalbikeshare-tripdata.csv.gz
# Processing file: 201912-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201912-capitalbikeshare-tripdata.csv.gz
# Processing file: 202405-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202405-capitalbikeshare-tripdata.csv.gz
# Processing file: 201811-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201811-capitalbikeshare-tripdata.csv.gz
# Processing file: 2010-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2010-capitalbikeshare-tripdata.csv.gz
# Processing file: 202308-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202308-capitalbikeshare-tripdata.csv.gz
# Processing file: 202001-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202001-capitalbikeshare-tripdata.csv.gz
# Processing file: 201904-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201904-capitalbikeshare-tripdata.csv.gz
# Processing file: 202203-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202203-capitalbikeshare-tripdata.csv.gz
# Processing file: 202307-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202307-capitalbikeshare-tripdata.csv.gz
# Processing file: 202105-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202105-capitalbikeshare-tripdata.csv.gz
# Processing file: 202212-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202212-capitalbikeshare-tripdata.csv.gz
# Processing file: 202501-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202501-capitalbikeshare-tripdata.csv.gz
# Processing file: 202010-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202010-capitalbikeshare-tripdata.csv.gz
# Processing file: 202008-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202008-capitalbikeshare-tripdata.csv.gz
# Processing file: 202301-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202301-capitalbikeshare-tripdata.csv.gz
# Processing file: 202412-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202412-capitalbikeshare-tripdata.csv.gz
# Processing file: 201806-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201806-capitalbikeshare-tripdata.csv.gz
# Processing file: 202103-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202103-capitalbikeshare-tripdata.csv.gz
# Processing file: 202007-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202007-capitalbikeshare-tripdata.csv.gz
# Processing file: 201902-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201902-capitalbikeshare-tripdata.csv.gz
# Processing file: 202205-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202205-capitalbikeshare-tripdata.csv.gz
# Processing file: 202112-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202112-capitalbikeshare-tripdata.csv.gz
# Processing file: 201809-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201809-capitalbikeshare-tripdata.csv.gz
# Processing file: 202403-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202403-capitalbikeshare-tripdata.csv.gz
# Processing file: 202310-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202310-capitalbikeshare-tripdata.csv.gz
# Processing file: 2016-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2016-capitalbikeshare-tripdata.csv.gz
# Processing file: 202011-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202011-capitalbikeshare-tripdata.csv.gz
# Processing file: 201801-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201801-capitalbikeshare-tripdata.csv.gz
# Processing file: 202104-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202104-capitalbikeshare-tripdata.csv.gz
# Processing file: 202306-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202306-capitalbikeshare-tripdata.csv.gz
# Processing file: 202202-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202202-capitalbikeshare-tripdata.csv.gz
# Processing file: 201905-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201905-capitalbikeshare-tripdata.csv.gz
# Processing file: 2011-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/2011-capitalbikeshare-tripdata.csv.gz
# Processing file: 202309-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202309-capitalbikeshare-tripdata.csv.gz
# Processing file: 202404-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/202404-capitalbikeshare-tripdata.csv.gz
# Processing file: 201810-capitalbikeshare-tripdata.zip...
# Successfully saved cleaned data to: /Users/vpry/Downloads/processed_data/201810-capitalbikeshare-tripdata.csv.gz
#
# All files have been processed.
