# %%
# data_column_lister.ipynb

# This script is designed to quickly list all column headers for each
# compressed CSV file (in .zip format) within a specified directory.
# It is useful for a quick check of data schema across multiple files.

# 1. Setup and Imports
# ==============================================================================
import os
import glob
import pandas as pd
import zipfile

# The directory containing your raw, compressed data files.
# Please ensure this path is correct.
RAW_DATA_DIR = '/Users/vpry/Downloads/bike_sharing_dataset'


# 2. Main Script Execution
# ==============================================================================
if __name__ == '__main__':
    # Step 2a: Use glob to find all .zip files in the specified directory.
    zip_files = glob.glob(os.path.join(RAW_DATA_DIR, '*.zip'))

    if not zip_files:
        print(f"No .zip files found in the directory: {RAW_DATA_DIR}. "
              "Please make sure your raw data files are there.")
    else:
        print(f"Found {len(zip_files)} files to check for columns.\n")
        
        # Step 2b: Loop through each file found.
        for file_path in zip_files:
            file_name = os.path.basename(file_path)
            try:
                # Step 2c: Open the zip file to inspect its contents.
                with zipfile.ZipFile(file_path, 'r') as zf:
                    # Find the actual CSV file inside the archive.
                    # This handles cases where extra files like __MACOSX are present.
                    csv_file_in_zip = None
                    for name in zf.namelist():
                        if name.endswith('.csv') and not name.startswith('__MACOSX'):
                            csv_file_in_zip = name
                            break
                    
                    if csv_file_in_zip:
                        # Step 2d: Read only the header of the specific CSV file.
                        # The 'nrows=0' parameter ensures that no data is loaded,
                        # making this process very fast.
                        df = pd.read_csv(zf.open(csv_file_in_zip), nrows=0)
                        
                        # Step 2e: Extract the column names.
                        columns = df.columns.tolist()
                        
                        # Step 2f: Print the file name and its columns in a readable format.
                        print(f"File: {file_name}")
                        print(f"  Columns: {', '.join(columns)}\n")
                    else:
                        print(f"An error occurred while processing {file_name}: No CSV file found in the archive.\n")

            except Exception as e:
                # Catch any errors that might occur during file reading
                # (e.g., file not a valid CSV, corruption, etc.).
                print(f"An error occurred while processing {file_name}: {e}\n")
# Out:
# Found 97 files to check for columns.
#
# File: 202210-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202503-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202012-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201909-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202305-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201802-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202408-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202107-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202003-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 201906-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202201-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202108-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202407-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 2012-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 201910-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202504-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202209-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201805-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202411-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202302-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202206-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201901-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 2015-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202111-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 2013-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202109-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201812-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202406-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202002-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 201907-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 201803-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202409-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202106-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202304-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202502-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201908-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202211-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202110-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202401-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202312-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 2014-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202005-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202207-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202303-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201804-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202410-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202101-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202208-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201911-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202505-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202311-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 2017-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 201808-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202402-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202204-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202006-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201903-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 201807-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202102-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202506-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202009-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201912-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202405-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201811-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 2010-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202308-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202001-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 201904-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202203-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202307-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202105-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202212-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202501-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202010-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202008-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202301-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202412-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201806-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202103-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202007-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201902-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202205-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202112-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201809-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202403-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202310-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 2016-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202011-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201801-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202104-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202306-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202202-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201905-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 2011-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
#
# File: 202309-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 202404-capitalbikeshare-tripdata.zip
#   Columns: ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual
#
# File: 201810-capitalbikeshare-tripdata.zip
#   Columns: Duration, Start date, End date, Start station number, Start station, End station number, End station, Bike number, Member type
